# %%
import pandas as pd

# %%
data= pd.read_csv("D:/EDHS file/2019 EDHS/ETKR81DT/ETKR81F.csv")

# %%
data
# Out:
#       Unnamed: 0           caseid  midx v000  v001  v002  v003  v004     v005  \
# 0              0      00010008 02     1  ET7     1     8     2     1  1543343
# 1              1      00010014 02     1  ET7     1    14     2     1  1543343
# 2              2      00010021 02     1  ET7     1    21     2     1  1543343
# 3              3      00010041 02     1  ET7     1    41     2     1  1543343
# 4              4      00010047 02     1  ET7     1    47     2     1  1543343
# ...          ...              ...   ...  ...   ...   ...   ...   ...      ...
# 5748        5748      03050166 02     1  ET7   305   166     2   305    57555
# 5749        5749      03050166 02     2  ET7   305   166     2   305    57555
# 5750        5750      03050171 02     1  ET7   305   171     2   305    57555
# 5751        5751      03050177 02     1  ET7   305   177     2   305    57555
# 5752        5752      03050177 02     2  ET7   305   177     2   305    57555
#
# ...

# %%
x=['caseid','b5','b9','b19','m4','m39a','v409','v411','v411a'
   ,'v412a','v412c','v414e','v414f','v414g','v414h','v414i',
   'v414j','v414k','v414l','v414m','v414n','v414o','v414p',
   'v414s','v414v','v005','v213','v445','v190','v457','v013','v130','v106','v024','v025']

# %%
data= pd.read_csv("D:/EDHS file/2019 EDHS/ETKR81DT/ETKR81F.csv", index_col='caseid',usecols=x)

# %%
data.head(100)
# Out:
#                     v005  v013  v024  v025  v106  v130  v190  v213  v409  \
# caseid
#     00010008 02  1543343     3     1     1     2     1     5     1   NaN
#     00010014 02  1543343     3     1     1     3     1     5     0   NaN
#     00010021 02  1543343     3     1     1     2     1     5     0   1.0
#     00010041 02  1543343     4     1     1     3     1     5     0   NaN
#     00010047 02  1543343     3     1     1     2     1     5     1   NaN
# ...                  ...   ...   ...   ...   ...   ...   ...   ...   ...
#     00060082 02   652857     2     1     2     1     1     2     1   1.0
#     00060086 02   652857     3     1     2     1     1     1     1   NaN
#     00060099 02   652857     4     1     2     0     1     1     0   1.0
#     00060099 02   652857     4     1     2     0     1     1     0   1.0
#     00070002 02   633933     3     1     2     0     1     1     1   NaN
#
#                  v411  ...  v414p  v414s  v414v  v445  v457  b5   b9  b19  m4  \
# ...

# %%
data.shape
# Out:
# (5753, 34)

# %%
data.isnull().sum().sum()
# Out:
# 60823

# %%
data.isnull().sum()
# Out:
# v005        0
# v013        0
# v024        0
# v025        0
# v106        0
# v130        0
# v190        0
# v213        0
# v409     2383
# v411     2383
# v411a    2383
# v412a    2383
# v412c    2383
# v414e    2383
# v414f    2383
# v414g    2383
# v414h    2383
# v414i    2383
# v414j    2383
# v414k    2383
# v414l    2383
# v414m    2383
# v414n    2383
# v414o    2383
# v414p    2383
# v414s    2383
# v414v    2383
# v445     5753
# v457     5753
# b5          0
# b9        339
# b19         0
# m4          0
# m39a     3701
# dtype: int64

# %%
data.to_csv('D:EDHS file/Data for implimation nutrrition/nutrition_2019.csv')

# %%
data1=pd.read_csv('D:EDHS file/Data for implimation nutrrition/nutrition_2019.csv')

# %%
data1.head(100)
# Out:
#              caseid     v005  v013  v024  v025  v106  v130  v190  v213  v409  \
# 0       00010008 02  1543343     3     1     1     2     1     5     1   NaN
# 1       00010014 02  1543343     3     1     1     3     1     5     0   NaN
# 2       00010021 02  1543343     3     1     1     2     1     5     0   1.0
# 3       00010041 02  1543343     4     1     1     3     1     5     0   NaN
# 4       00010047 02  1543343     3     1     1     2     1     5     1   NaN
# ..              ...      ...   ...   ...   ...   ...   ...   ...   ...   ...
# 95      00060082 02   652857     2     1     2     1     1     2     1   1.0
# 96      00060086 02   652857     3     1     2     1     1     1     1   NaN
# 97      00060099 02   652857     4     1     2     0     1     1     0   1.0
# 98      00060099 02   652857     4     1     2     0     1     1     0   1.0
# 99      00070002 02   633933     3     1     2     0     1     1     1   NaN
#
# ...

# %%
data1.shape
# Out:
# (5753, 35)
