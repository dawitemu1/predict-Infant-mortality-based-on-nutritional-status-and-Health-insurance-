# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_csv("D:/Malnutration/EDHS file/Data for implimation nutrrition/nutrition.csv",sep=',',index_col='caseid')

# %%
dataset
# Out:
#                  Unnamed: 0     v005  v013  v024  v025  v106  v130  v190  \
# caseid
#        1  17  2           0  5087433     5     4     2     0     4     2
#        1  17  2           1  5087433     5     4     2     0     4     2
#        1  17  2           2  5087433     5     4     2     0     4     2
#        1  18  2           3  5087433     6     4     2     1     4     2
#        1  25  2           4  5087433     7     4     2     0     4     2
# ...                     ...      ...   ...   ...   ...   ...   ...   ...
#     03050166 02        5748    57555     2    11     2     0     4     2
#     03050166 02        5749    57555     2    11     2     0     4     2
#     03050171 02        5750    57555     4    11     2     1     4     1
#     03050177 02        5751    57555     4    11     2     0     4     2
#     03050177 02        5752    57555     4    11     2     0     4     2
#
#                  v213  v409  ...  v414p  v414s  v414v    v445  v457  b5   b9  \
# ...

# %%
dataset.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
dataset.duplicated().sum()
# Out:
# 112

# %%
dataset.isnull().sum().sum()
# Out:
# 145596

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.shape
# Out:
# (16282, 34)

# %%
dataset.columns
# Out:
# Index(['v005', 'v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409',
#        'v411', 'v411a', 'v412a', 'v412c', 'v414e', 'v414f', 'v414g', 'v414h',
#        'v414i', 'v414j', 'v414k', 'v414l', 'v414m', 'v414n', 'v414o', 'v414p',
#        'v414s', 'v414v', 'v445', 'v457', 'b5', 'b9', 'b19', 'm4', 'm39a'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (16282, 34)

# %%
dataset.columns
# Out:
# Index(['v005', 'v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409',
#        'v411', 'v411a', 'v412a', 'v412c', 'v414e', 'v414f', 'v414g', 'v414h',
#        'v414i', 'v414j', 'v414k', 'v414l', 'v414m', 'v414n', 'v414o', 'v414p',
#        'v414s', 'v414v', 'v445', 'v457', 'b5', 'b9', 'b19', 'm4', 'm39a'],
#       dtype='object')

# %%
data1 = dataset.loc[:,dataset.columns != 'b5']
data2 = dataset.loc[:,dataset.columns =='b5']

# %%
for l, k in enumerate(data1.columns):
      print(k, ' == >> ',data1[k].unique())
# Out:
# v005  == >>  [5087433  461695 2150055   78850   67744  166429  415601  263005  273461
#  2092998  462503 2069881   54345 1402739  556598  134889  170374 1109392
#   418612 1688765 2004397  340149 2354972 2209779  111757 2944390   59856
#    20709   52982   71959  560100 2112978  223651 1599740  140961   97632
#    70855 1896780   26589 2532077 1737402 2885775  195201   40918  604337
#    37168   55984  117169  145599 1438423  190131 3328477 1938935 1615517
#    14567   42222  335768   37058  349625   48692  596064 2805615   40995
#   171758  145815 2629856   41074    9276  262246  165040  298744 2352930
#    70002  119701 1605871  105286  645477  512367 1813932  754952  194855
#   558620  740625  911342 1937960 1700023  262621  669616  382735  463867
#   282490 3024497  703478  296928  333797  607506  547941  511220  527982
#    96499   58475  460206   13138   27890   25620  406922  447048 2052672
#   672066   59867  545426 1541839   52120   44040  311202   95886 3112172
# ...

# %%
dataset.drop(['v005'], axis=1, inplace=True)
dataset.drop(['m39a'], axis=1, inplace=True)

# %%
dataset.columns
# Out:
# Index(['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
#        'v411a', 'v412a', 'v412c', 'v414e', 'v414f', 'v414g', 'v414h', 'v414i',
#        'v414j', 'v414k', 'v414l', 'v414m', 'v414n', 'v414o', 'v414p', 'v414s',
#        'v414v', 'v445', 'v457', 'b5', 'b9', 'b19', 'm4'],
#       dtype='object')

# %%
for i in data1.columns:
    data1[i] = pd.to_numeric(data1[i], errors='coerce')
# Out:
# C:\Users\Dawit Shibabaw\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset.isnull().sum().sum()
# Out:
# 133450

# %%
dataset.isnull().sum()
# Out:
# v013        0
# v024        0
# v025        0
# v106        0
# v130        0
# v190        0
# v213        0
# v409     6324
# v411     6324
# v411a    6324
# v412a    6324
# v412c    6324
# v414e    6324
# v414f    6324
# v414g    6324
# v414h    6324
# v414i    6324
# v414j    6324
# v414k    6324
# v414l    6324
# v414m    6324
# v414n    6324
# v414o    6324
# v414p    6324
# v414s    6324
# v414v    6324
# v445     6081
# v457     6263
# b5          0
# b9        950
# b19         0
# m4          0
# dtype: int64

# %%
def missing_values_table(dataset):
        # Total missing values
        mis_val = dataset.isnull().sum()
        # Percentage of missing values
        mis_val_percent = 100 * dataset.isnull().sum() / len(dataset)
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Number of Missing Values', 1 : 'Percentage(%)'})
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        'Percentage(%)', ascending=False).round(1)
        # Print some summary information
        print ("The dataset has a total of " + str(dataset.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(dataset)
# Out:
# The dataset has a total of 32 columns.
# There are 22 columns that have missing values.
#        Number of Missing Values  Percentage(%)
# v409                       6324           38.8
# v414j                      6324           38.8
# v414v                      6324           38.8
# v414s                      6324           38.8
# v414p                      6324           38.8
# v414o                      6324           38.8
# v414n                      6324           38.8
# v414m                      6324           38.8
# v414l                      6324           38.8
# v411                       6324           38.8
# v414k                      6324           38.8
# v414i                      6324           38.8
# v414h                      6324           38.8
# v414g                      6324           38.8
# v414f                      6324           38.8
# v414e                      6324           38.8
# v412c                      6324           38.8
# ...

# %%
miss_value=missing_values_table(dataset)
miss_value
# Out:
# The dataset has a total of 32 columns.
# There are 22 columns that have missing values.
#        Number of Missing Values  Percentage(%)
# v409                       6324           38.8
# v414j                      6324           38.8
# v414v                      6324           38.8
# v414s                      6324           38.8
# v414p                      6324           38.8
# v414o                      6324           38.8
# v414n                      6324           38.8
# v414m                      6324           38.8
# v414l                      6324           38.8
# v411                       6324           38.8
# v414k                      6324           38.8
# v414i                      6324           38.8
# v414h                      6324           38.8
# v414g                      6324           38.8
# v414f                      6324           38.8
# v414e                      6324           38.8
# v412c                      6324           38.8
# ...

# %%
dataset.dtypes
# Out:
# v013       int64
# v024       int64
# v025       int64
# v106       int64
# v130       int64
# v190       int64
# v213       int64
# v409     float64
# v411     float64
# v411a    float64
# v412a    float64
# v412c    float64
# v414e    float64
# v414f    float64
# v414g    float64
# v414h    float64
# v414i    float64
# v414j    float64
# v414k    float64
# v414l    float64
# v414m    float64
# v414n    float64
# v414o    float64
# v414p    float64
# v414s    float64
# v414v    float64
# v445     float64
# v457     float64
# b5         int64
# b9       float64
# b19        int64
# m4         int64
# dtype: object

# %%
for i in dataset.columns:
    dataset[i] = pd.to_numeric(dataset[i], errors='coerce')

# %%
dataset.dtypes
# Out:
# v013       int64
# v024       int64
# v025       int64
# v106       int64
# v130       int64
# v190       int64
# v213       int64
# v409     float64
# v411     float64
# v411a    float64
# v412a    float64
# v412c    float64
# v414e    float64
# v414f    float64
# v414g    float64
# v414h    float64
# v414i    float64
# v414j    float64
# v414k    float64
# v414l    float64
# v414m    float64
# v414n    float64
# v414o    float64
# v414p    float64
# v414s    float64
# v414v    float64
# v445     float64
# v457     float64
# b5         int64
# b9       float64
# b19        int64
# m4         int64
# dtype: object

# %%
# Shows the columns with their number of catagories each variable is having
for col in dataset.columns:
    print(col, ':', len(dataset[col].unique()), 'catagories')
# Out:
# v013 : 7 catagories
# v024 : 11 catagories
# v025 : 2 catagories
# v106 : 4 catagories
# v130 : 6 catagories
# v190 : 5 catagories
# v213 : 2 catagories
# v409 : 4 catagories
# v411 : 4 catagories
# v411a : 4 catagories
# v412a : 4 catagories
# v412c : 4 catagories
# v414e : 4 catagories
# v414f : 4 catagories
# v414g : 4 catagories
# v414h : 4 catagories
# v414i : 4 catagories
# v414j : 4 catagories
# v414k : 4 catagories
# v414l : 4 catagories
# v414m : 4 catagories
# v414n : 4 catagories
# v414o : 4 catagories
# v414p : 4 catagories
# v414s : 4 catagories
# v414v : 4 catagories
# v445 : 1442 catagories
# v457 : 5 catagories
# b5 : 2 catagories
# b9 : 3 catagories
# b19 : 60 catagories
# m4 : 3 catagories

# %%
dataset['b5'] = dataset['b5'].apply(np.int64)

# %%
# list of numerical variables
numerical_features = [feature for feature in dataset.columns if dataset[feature].dtypes != 'O']
print('Number of numerical variables: ', len(numerical_features))
# visualise the numerical variables
dataset[numerical_features].sample(5)
# Out:
# Number of numerical variables:  32
#                  v013  v024  v025  v106  v130  v190  v213  v409  v411  v411a  \
# caseid
#     01020054 02     3     4     2     1     1     3     0   1.0   0.0    0.0
#      297 235  5     2     7     1     1     3     5     0   0.0   0.0    0.0
#      456 196  2     2     3     2     0     1     3     0   0.0   0.0    0.0
#      351 435  2     4     1     2     0     1     3     0   NaN   NaN    NaN
#      604 479  2     5     1     2     1     1     1     0   1.0   0.0    0.0
#
#                  ...  v414o  v414p  v414s  v414v    v445  v457  b5   b9  b19  \
# caseid           ...
#     01020054 02  ...    1.0    0.0    1.0    0.0     NaN   NaN   1  0.0   34
#      297 235  5  ...    0.0    0.0    0.0    0.0  2050.0   4.0   1  0.0    0
#      456 196  2  ...    0.0    0.0    0.0    0.0  2247.0   3.0   1  0.0    5
#      351 435  2  ...    NaN    NaN    NaN    NaN  1764.0   4.0   1  0.0   29
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)
# Out:
# C:\Users\Dawit Shibabaw\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Dawit Shibabaw\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#get correlations of each features in dataset
corrmat = dataset.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,8))
#plot heat map
g=sns.heatmap(dataset[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
dataset.isnull().sum()
# Out:
# v013        0
# v024        0
# v025        0
# v106        0
# v130        0
# v190        0
# v213        0
# v409     6324
# v411     6324
# v411a    6324
# v412a    6324
# v412c    6324
# v414e    6324
# v414f    6324
# v414g    6324
# v414h    6324
# v414i    6324
# v414j    6324
# v414k    6324
# v414l    6324
# v414m    6324
# v414n    6324
# v414o    6324
# v414p    6324
# v414s    6324
# v414v    6324
# v445     6081
# v457     6263
# b5          0
# b9        950
# b19         0
# m4          0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
#        'v411a', 'v412a', 'v412c', 'v414e', 'v414f', 'v414g', 'v414h', 'v414i',
#        'v414j', 'v414k', 'v414l', 'v414m', 'v414n', 'v414o', 'v414p', 'v414s',
#        'v414v', 'v445', 'v457', 'b5', 'b9', 'b19', 'm4'],
#       dtype='object')

# %%
dataset['v409'].fillna(dataset['v409'].mode()[0], inplace=True)
dataset['v411'].fillna(dataset['v411'].mode()[0], inplace=True)
dataset['v411a'].fillna(dataset['v411a'].mode()[0], inplace=True)
dataset['v412a'].fillna(dataset['v412a'].mode()[0], inplace=True)
dataset['v412c'].fillna(dataset['v412c'].mode()[0], inplace=True)
dataset['v414e'].fillna(dataset['v414f'].mode()[0], inplace=True)
dataset['v414f'].fillna(dataset['v414f'].mode()[0], inplace=True)
dataset['v414g'].fillna(dataset['v414g'].mode()[0], inplace=True)
dataset['v414h'].fillna(dataset['v414h'].mode()[0], inplace=True)
dataset['v414i'].fillna(dataset['v414i'].mode()[0], inplace=True)
dataset['v414j'].fillna(dataset['v414j'].mode()[0], inplace=True)
dataset['v414k'].fillna(dataset['v414k'].mode()[0], inplace=True)
dataset['v414l'].fillna(dataset['v414l'].mode()[0], inplace=True)
#dataset['m49a'].fillna(dataset['m49a'].mode()[0], inplace=True)
dataset['v414m'].fillna(dataset['v414m'].mode()[0], inplace=True)
dataset['v414n'].fillna(dataset['v414n'].mode()[0], inplace=True)
dataset['v414o'].fillna(dataset['v414o'].mode()[0], inplace=True)
dataset['v414p'].fillna(dataset['v414p'].mode()[0], inplace=True)
dataset['v414s'].fillna(dataset['v414s'].mode()[0], inplace=True)
dataset['v414v'].fillna(dataset['v414v'].mode()[0], inplace=True)
dataset['v445'].fillna(dataset['v445'].mode()[0], inplace=True)
dataset['v457'].fillna(dataset['v457'].mode()[0], inplace=True)
dataset['b9'].fillna(dataset['b9'].mode()[0], inplace=True)
dataset['b19'].fillna(dataset['b19'].mode()[0], inplace=True)

# %%
dataset.isnull().sum()
# Out:
# v013     0
# v024     0
# v025     0
# v106     0
# v130     0
# v190     0
# v213     0
# v409     0
# v411     0
# v411a    0
# v412a    0
# v412c    0
# v414e    0
# v414f    0
# v414g    0
# v414h    0
# v414i    0
# v414j    0
# v414k    0
# v414l    0
# v414m    0
# v414n    0
# v414o    0
# v414p    0
# v414s    0
# v414v    0
# v445     0
# v457     0
# b5       0
# b9       0
# b19      0
# m4       0
# dtype: int64

# %%
dataset.shape
# Out:
# (16282, 32)

# %%
dataset.duplicated().sum()
# Out:
# 138

# %%
for t in dataset.columns:
    if dataset[t].duplicated().sum() == 0:
        print(t)

# %%
dataset
# Out:
#                  v013  v024  v025  v106  v130  v190  v213  v409  v411  v411a  \
# caseid
#        1  17  2     5     4     2     0     4     2     0   1.0   0.0    0.0
#        1  17  2     5     4     2     0     4     2     0   1.0   0.0    0.0
#        1  17  2     5     4     2     0     4     2     0   1.0   0.0    0.0
#        1  18  2     6     4     2     1     4     2     0   1.0   0.0    0.0
#        1  25  2     7     4     2     0     4     2     0   1.0   0.0    0.0
# ...               ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
#     03050166 02     2    11     2     0     4     2     0   1.0   0.0    0.0
#     03050166 02     2    11     2     0     4     2     0   1.0   0.0    0.0
#     03050171 02     4    11     2     1     4     1     1   1.0   0.0    0.0
#     03050177 02     4    11     2     0     4     2     0   1.0   0.0    0.0
#     03050177 02     4    11     2     0     4     2     0   1.0   0.0    0.0
#
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                  v013  v024  v025  v106  v130  v190  v213  v409  v411  v411a  \
# caseid
#        1  17  2     5     4     2     0     4     2     0   1.0   0.0    0.0
#        1  17  2     5     4     2     0     4     2     0   1.0   0.0    0.0
#        1  17  2     5     4     2     0     4     2     0   1.0   0.0    0.0
#        1  18  2     6     4     2     1     4     2     0   1.0   0.0    0.0
#        1  25  2     7     4     2     0     4     2     0   1.0   0.0    0.0
# ...               ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
#     03050166 02     2    11     2     0     4     2     0   1.0   0.0    0.0
#     03050166 02     2    11     2     0     4     2     0   1.0   0.0    0.0
#     03050171 02     4    11     2     1     4     1     1   1.0   0.0    0.0
#     03050177 02     4    11     2     0     4     2     0   1.0   0.0    0.0
#     03050177 02     4    11     2     0     4     2     0   1.0   0.0    0.0
#
# ...

# %%
dataset.dtypes
# Out:
# v013       int64
# v024       int64
# v025       int64
# v106       int64
# v130       int64
# v190       int64
# v213       int64
# v409     float64
# v411     float64
# v411a    float64
# v412a    float64
# v412c    float64
# v414e    float64
# v414f    float64
# v414g    float64
# v414h    float64
# v414i    float64
# v414j    float64
# v414k    float64
# v414l    float64
# v414m    float64
# v414n    float64
# v414o    float64
# v414p    float64
# v414s    float64
# v414v    float64
# v445     float64
# v457     float64
# b5         int64
# b9       float64
# b19        int64
# m4         int64
# dtype: object

# %%
dataset.dtypes
for x in dataset:
    if dataset[x].dtypes == "float64":
        dataset[x] = dataset[x].astype(int)
        print (dataset[x].dtypes)
# Out:
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32

# %%
dataset.dtypes
# Out:
# v013     int64
# v024     int64
# v025     int64
# v106     int64
# v130     int64
# v190     int64
# v213     int64
# v409     int32
# v411     int32
# v411a    int32
# v412a    int32
# v412c    int32
# v414e    int32
# v414f    int32
# v414g    int32
# v414h    int32
# v414i    int32
# v414j    int32
# v414k    int32
# v414l    int32
# v414m    int32
# v414n    int32
# v414o    int32
# v414p    int32
# v414s    int32
# v414v    int32
# v445     int32
# v457     int32
# b5       int64
# b9       int32
# b19      int64
# m4       int64
# dtype: object

# %%
dataset.dtypes
for x in dataset:
    if dataset[x].dtypes == "int64":
        dataset[x] = dataset[x].astype(int)
        print (dataset[x].dtypes)
# Out:
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32

# %%
dataset.dtypes
# Out:
# v013     int32
# v024     int32
# v025     int32
# v106     int32
# v130     int32
# v190     int32
# v213     int32
# v409     int32
# v411     int32
# v411a    int32
# v412a    int32
# v412c    int32
# v414e    int32
# v414f    int32
# v414g    int32
# v414h    int32
# v414i    int32
# v414j    int32
# v414k    int32
# v414l    int32
# v414m    int32
# v414n    int32
# v414o    int32
# v414p    int32
# v414s    int32
# v414v    int32
# v445     int32
# v457     int32
# b5       int32
# b9       int32
# b19      int32
# m4       int32
# dtype: object

# %%
dataset['m4'].astype(np.float64).astype("Int32")
# Out:
# caseid
#        1  17  2    93
#        1  17  2    93
#        1  17  2    93
#        1  18  2    93
#        1  25  2    93
#                    ..
#     03050166 02    95
#     03050166 02    93
#     03050171 02    93
#     03050177 02    95
#     03050177 02    93
# Name: m4, Length: 16282, dtype: Int32

# %%
dataset.isnull().sum()
# Out:
# v013     0
# v024     0
# v025     0
# v106     0
# v130     0
# v190     0
# v213     0
# v409     0
# v411     0
# v411a    0
# v412a    0
# v412c    0
# v414e    0
# v414f    0
# v414g    0
# v414h    0
# v414i    0
# v414j    0
# v414k    0
# v414l    0
# v414m    0
# v414n    0
# v414o    0
# v414p    0
# v414s    0
# v414v    0
# v445     0
# v457     0
# b5       0
# b9       0
# b19      0
# m4       0
# dtype: int64

# %%
dataset.dtypes
# Out:
# v013     int32
# v024     int32
# v025     int32
# v106     int32
# v130     int32
# v190     int32
# v213     int32
# v409     int32
# v411     int32
# v411a    int32
# v412a    int32
# v412c    int32
# v414e    int32
# v414f    int32
# v414g    int32
# v414h    int32
# v414i    int32
# v414j    int32
# v414k    int32
# v414l    int32
# v414m    int32
# v414n    int32
# v414o    int32
# v414p    int32
# v414s    int32
# v414v    int32
# v445     int32
# v457     int32
# b5       int32
# b9       int32
# b19      int32
# m4       int32
# dtype: object

# %%
dataset['v409'] = dataset['v409'].astype(np.int64)
dataset['v411'] = dataset['v411'].astype(np.int64)
dataset['v411a'] = dataset['v411a'].astype(np.int64)
dataset['v412a'] = dataset['v412a'].astype(np.int64)
dataset['v412c'] = dataset['v412c'].astype(np.int64)
dataset['v414e'] = dataset['v414e'].astype(np.int64)
dataset['v414f'] = dataset['v414f'].astype(np.int64)
dataset['v414g'] = dataset['v414g'].astype(np.int64)
dataset['v414h'] = dataset['v414h'].astype(np.int64)
dataset['v414i'] = dataset['v414i'].astype(np.int64)
dataset['v414j'] = dataset['v414j'].astype(np.int64)
dataset['v414k'] = dataset['v414k'].astype(np.int64)
dataset['v414l'] = dataset['v414l'].astype(np.int64)
dataset['v414m'] = dataset['v414m'].astype(np.int64)
dataset['v414n'] = dataset['v414n'].astype(np.int64)
dataset['v414o'] = dataset['v414o'].astype(np.int64)
dataset['v414p'] = dataset['v414p'].astype(np.int64)
dataset['v414s'] = dataset['v414s'].astype(np.int64)
dataset['v414v'] = dataset['v414v'].astype(np.int64)
dataset['v445'] = dataset['v445'].astype(np.int64)
dataset['v457'] = dataset['v457'].astype(np.int64)
dataset['b9'] = dataset['b9'].astype(np.int64)

# %%
dataset.dtypes
# Out:
# v013     int32
# v024     int32
# v025     int32
# v106     int32
# v130     int32
# v190     int32
# v213     int32
# v409     int64
# v411     int64
# v411a    int64
# v412a    int64
# v412c    int64
# v414e    int64
# v414f    int64
# v414g    int64
# v414h    int64
# v414i    int64
# v414j    int64
# v414k    int64
# v414l    int64
# v414m    int64
# v414n    int64
# v414o    int64
# v414p    int64
# v414s    int64
# v414v    int64
# v445     int64
# v457     int64
# b5       int32
# b9       int64
# b19      int32
# m4       int32
# dtype: object

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                  v013  v024  v025  v106  v130  v190  v213  v409  v411  v411a  \
# caseid
#        1  17  2     5     4     2     0     4     2     0     1     0      0
#        1  17  2     5     4     2     0     4     2     0     1     0      0
#        1  17  2     5     4     2     0     4     2     0     1     0      0
#        1  18  2     6     4     2     1     4     2     0     1     0      0
#        1  25  2     7     4     2     0     4     2     0     1     0      0
# ...               ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
#     03050166 02     2    11     2     0     4     2     0     1     0      0
#     03050166 02     2    11     2     0     4     2     0     1     0      0
#     03050171 02     4    11     2     1     4     1     1     1     0      0
#     03050177 02     4    11     2     0     4     2     0     1     0      0
#     03050177 02     4    11     2     0     4     2     0     1     0      0
#
# ...

# %% [markdown]
# # Data transformation

# %%
dataset['b5'].value_counts()
# Out:
# 1    15332
# 0      950
# Name: b5, dtype: int64

# %%
dataset['v013'].value_counts()
# Out:
# 3    4981
# 4    3573
# 2    3304
# 5    2436
# 6     978
# 1     699
# 7     311
# Name: v013, dtype: int64

# %%
#dataset.loc[dataset.v013 ==3 ,'v013'] = 1;
#dataset.loc[dataset.v013 ==4 ,'v013'] = 0;
#dataset.loc[dataset.v013 ==5 ,'v013'] = 1;
#dataset.loc[dataset.v013 ==6 ,'v013'] = 0;
#dataset.loc[dataset.v013 ==7 ,'v013'] = 0;
#dataset.loc[dataset.v013 ==1 ,'v013'] = 0;
dataset['v013'].value_counts()
# Out:
# 3    4981
# 4    3573
# 2    3304
# 5    2436
# 6     978
# 1     699
# 7     311
# Name: v013, dtype: int64

# %%
dataset.to_csv("D:/Malnutration/EDHS file/Data for implimation nutrrition/nutrition.csv")

# %%
dataset['v024'].value_counts()
# Out:
# 4     2287
# 5     2122
# 7     1927
# 2     1700
# 3     1482
# 1     1482
# 6     1394
# 8     1156
# 9     1046
# 11     941
# 10     745
# Name: v024, dtype: int64

# %%
dataset['v025'].value_counts()
# Out:
# 2    13007
# 1     3275
# Name: v025, dtype: int64

# %%
dataset['v106'].value_counts()
# Out:
# 0    9916
# 1    4474
# 2    1204
# 3     688
# Name: v106, dtype: int64

# %%
dataset['v130'].value_counts()
# Out:
# 4     8354
# 1     4664
# 3     2896
# 5      164
# 2      104
# 96     100
# Name: v130, dtype: int64

# %%
dataset.loc[dataset.v130 ==3 ,'v130'] = 1;
dataset.loc[dataset.v130 ==4 ,'v130'] = 0;
dataset.loc[dataset.v130 ==5 ,'v130'] = 1;
dataset.loc[dataset.v130 ==96 ,'v130'] = 0;
#dataset.loc[dataset.v130 ==7 ,'v130'] = 0;
dataset['v130'].value_counts()
# Out:
# 0    8454
# 1    7724
# 2     104
# Name: v130, dtype: int64

# %%
dataset['v190'].value_counts()
# Out:
# 1    5912
# 5    3322
# 2    2760
# 3    2252
# 4    2036
# Name: v190, dtype: int64

# %%
#dataset.loc[dataset.v190 ==5 ,'v190'] = 0;
#dataset.loc[dataset.v190 ==4 ,'v190'] = 0;
dataset['v130'].value_counts()
# Out:
# 0    8454
# 1    7724
# 2     104
# Name: v130, dtype: int64

# %%
dataset['v213'].value_counts()
# Out:
# 0    14463
# 1     1819
# Name: v213, dtype: int64

# %%
dataset['v411a'].value_counts()
# Out:
# 0    15948
# 1      251
# 8       83
# Name: v411a, dtype: int64

# %%
dataset.loc[dataset.v411a ==8 ,'v411a'] = 1;
dataset['v411a'].value_counts()
# Out:
# 0    15948
# 1      334
# Name: v411a, dtype: int64

# %%
dataset.loc[dataset.v409 ==8 ,'v409'] = 1;
dataset['v409'].value_counts()
# Out:
# 1    13514
# 0     2768
# Name: v409, dtype: int64

# %%
dataset.loc[dataset.v411 ==8 ,'v411'] = 1;
dataset['v411'].value_counts()
# Out:
# 0    13719
# 1     2563
# Name: v411, dtype: int64

# %%
dataset.loc[dataset.v412a ==8 ,'v412a'] = 1;
dataset['v412a'].value_counts()
# Out:
# 0    15857
# 1      425
# Name: v412a, dtype: int64

# %%
dataset.loc[dataset.v412c ==8 ,'v412c'] = 1;
dataset['v412c'].value_counts()
# Out:
# 0    15624
# 1      658
# Name: v412c, dtype: int64

# %%
dataset.loc[dataset.v414e ==8 ,'v414e'] = 1;
dataset['v414e'].value_counts()
# Out:
# 0    12144
# 1     4138
# Name: v414e, dtype: int64

# %%
dataset.loc[dataset.v414f ==8 ,'v414f'] = 1;
dataset['v414f'].value_counts()
# Out:
# 0    14930
# 1     1352
# Name: v414f, dtype: int64

# %%
dataset.loc[dataset.v414g ==8 ,'v414g'] = 1;
dataset['v414g'].value_counts()
# Out:
# 0    15188
# 1     1094
# Name: v414g, dtype: int64

# %%
dataset.loc[dataset.v414h ==8 ,'v414h'] = 1;
dataset['v414h'].value_counts()
# Out:
# 0    15873
# 1      409
# Name: v414h, dtype: int64

# %%
dataset.loc[dataset.v414i ==8 ,'v414i'] = 1;
dataset['v414i'].value_counts()
# Out:
# 0    15412
# 1      870
# Name: v414i, dtype: int64

# %%
dataset.loc[dataset.v414j ==8 ,'v414j'] = 1;
dataset['v414j'].value_counts()
# Out:
# 0    15525
# 1      757
# Name: v414j, dtype: int64

# %%
dataset.loc[dataset.v414k ==8 ,'v414k'] = 1;
dataset['v414k'].value_counts()
# Out:
# 0    15409
# 1      873
# Name: v414k, dtype: int64

# %%
dataset.loc[dataset.v414l ==8 ,'v414l'] = 1;
dataset['v414l'].value_counts()
# Out:
# 0    15568
# 1      714
# Name: v414l, dtype: int64

# %%
dataset.loc[dataset.v414m ==8 ,'v414m'] = 1;
dataset['v414m'].value_counts()
# Out:
# 0    16046
# 1      236
# Name: v414m, dtype: int64

# %%
dataset.loc[dataset.v414n ==8 ,'v414n'] = 1;
dataset['v414n'].value_counts()
# Out:
# 0    16077
# 1      205
# Name: v414n, dtype: int64

# %%
dataset.loc[dataset.v414o ==8 ,'v414o'] = 1;
dataset['v414o'].value_counts()
# Out:
# 0    15063
# 1     1219
# Name: v414o, dtype: int64

# %%
dataset.loc[dataset.v414p ==8 ,'v414p'] = 1;
dataset['v414p'].value_counts()
# Out:
# 0    15162
# 1     1120
# Name: v414p, dtype: int64

# %%
dataset.loc[dataset.v414s ==8 ,'v414s'] = 1;
dataset['v414s'].value_counts()
# Out:
# 0    13799
# 1     2483
# Name: v414s, dtype: int64

# %%
dataset.loc[dataset.v414v ==8 ,'v414v'] = 1;
dataset['v414v'].value_counts()
# Out:
# 0    15704
# 1      578
# Name: v414v, dtype: int64

# %%
dataset.loc[dataset.b9 ==4 ,'b9'] = 1;
dataset['b9'].value_counts()
# Out:
# 0    15904
# 1      378
# Name: b9, dtype: int64

# %%
dataset.loc[dataset.m4 ==93 ,'m4'] = 1;
dataset.loc[dataset.m4 ==95 ,'m4'] = 0;
dataset.loc[dataset.m4 ==94 ,'m4'] = 1;
dataset['m4'].value_counts()
# Out:
# 1    9804
# 0    6478
# Name: m4, dtype: int64

# %%
#dataset.loc[dataset.b19 ==4 ,'b19'] = 1;
dataset['b19'].value_counts()
# Out:
# 48    396
# 49    366
# 36    358
# 25    353
# 51    350
# 50    349
# 12    349
# 24    347
# 52    341
# 38    332
# 13    329
# 5     324
# 6     320
# 39    317
# 26    315
# 41    307
# 0     307
# 53    305
# 37    299
# 4     298
# 28    298
# 40    289
# 29    288
# 8     286
# 2     281
# 54    280
# 15    278
# 3     272
# 9     270
# 1     269
# 42    269
# 17    268
# 16    268
# 14    267
# 27    266
# 18    260
# 30    259
# 7     256
# 11    256
# 19    246
# 55    235
# 23    228
# 31    224
# 32    223
# 43    221
# 56    221
# 59    216
# 10    215
# 35    213
# 22    206
# 33    204
# 20    204
# 46    203
# 44    200
# 58    200
# 34    199
# 45    197
# 21    196
# 47    195
# 57    194
# Name: b19, dtype: int64

# %%
dataset.loc[dataset.v445 ==1881 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1984 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1940 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1908 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2156 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2506 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2490 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2474 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2466 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2979 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1965 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1915 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2071 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1959 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1458 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3459 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2432 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1386 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2694 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1906 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2051 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1918 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1362 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3507 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1514 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1562 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2874 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2112 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1941 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2031 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2669 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2558 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2693 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2566 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3182 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2085 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1859 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2108 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2719 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2923 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2939 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2742 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2927 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2053 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1922 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1936 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2533 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2517 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2445 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2341 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2973 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1888 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2127 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1981 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2941 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2909 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1550 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2789 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2914 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1919 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1892 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1932 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3398 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3252 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2563 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1399 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3572 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2171 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2070 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1929 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2895 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2887 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3188 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1457 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2839 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1977 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1852 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1927 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1585 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1617 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2716 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3704 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1486 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2011 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1969 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1966 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2624 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3461 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1467 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2674 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3179 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2011 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1969 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1966 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2624 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3461 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1467 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2674 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3179 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1989 ,'v445'] = 1;
dataset.loc[dataset.v445 ==2004 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1996 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2615 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1463 ,'v445'] = 0;
dataset.loc[dataset.v445 ==1487 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2591 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3351 ,'v445'] = 0;

dataset.loc[dataset.v445 ==2029 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1972 ,'v445'] = 1;
dataset.loc[dataset.v445 ==1830 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2954 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2882 ,'v445'] = 0;
dataset.loc[dataset.v445 ==3718 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2919 ,'v445'] = 0;
dataset.loc[dataset.v445 ==2478 ,'v445'] = 0;
dataset['v445'].value_counts()
# Out:
# 1       6670
# 0        474
# 2020      22
# 1866      22
# 1925      22
#         ...
# 1551       1
# 3074       1
# 1567       1
# 3090       1
# 3083       1
# Name: v445, Length: 1336, dtype: int64

# %%
dataset.loc[dataset.v457 ==4 ,'v457'] = 1;
dataset.loc[dataset.v457 ==3,'v457'] = 1;
dataset.loc[dataset.v457 ==2,'v457'] = 0;
dataset['v457'].value_counts()
# Out:
# 1    15243
# 0     1039
# Name: v457, dtype: int64

# %%
print(dataset.corr()["b5"].abs().sort_values(ascending=False))
# Out:
# b5       1.000000
# m4       0.202340
# v414e    0.061048
# b19      0.051671
# v409     0.049179
# v414f    0.045470
# v213     0.041478
# v414g    0.040641
# v414s    0.039995
# v130     0.038760
# b9       0.038376
# v106     0.038045
# v025     0.036007
# v414o    0.035966
# v414k    0.032496
# v457     0.030422
# v414l    0.030275
# v414i    0.030014
# v414j    0.028832
# v412c    0.028464
# v412a    0.027605
# v411     0.027011
# v414p    0.025207
# v414h    0.023213
# v411a    0.021235
# v414m    0.019226
# v190     0.011776
# v013     0.007059
# v414n    0.006958
# v414v    0.006690
# v445     0.003661
# v024     0.002412
# Name: b5, dtype: float64

# %%
# Using Matplotlib to show distribution of reviews sentiment in the dataset
import matplotlib.pyplot as plt
print(dataset.v457.value_counts())
dataset['b5'].value_counts().plot(kind='bar')
plt.title("infant moartality", size=18)
# Out:
# 1    15243
# 0     1039
# Name: v457, dtype: int64
# Text(0.5, 1.0, 'infant moartality')

# %%
dataset.to_csv("D:EDHS file/Data for implimation nutrrition/nutrition1.csv")

# %%
dataset.columns
# Out:
# Index(['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
#        'v411a', 'v412a', 'v412c', 'v414e', 'v414f', 'v414g', 'v414h', 'v414i',
#        'v414j', 'v414k', 'v414l', 'v414m', 'v414n', 'v414o', 'v414p', 'v414s',
#        'v414v', 'v445', 'v457', 'b5', 'b9', 'b19', 'm4'],
#       dtype='object')

# %%
x=dataset[['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
       'v411a', 'v412a', 'v412c', 'v414e', 'v414f', 'v414g', 'v414h', 'v414i',
       'v414j', 'v414k', 'v414l', 'v414m', 'v414n', 'v414o', 'v414p', 'v414s',
       'v414v', 'v445', 'v457','b9', 'b19', 'm4']]
y=dataset['b5']

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X_smote, y_smote = sm.fit_resample(x, y)
from collections import Counter
print(sorted(Counter(y_smote).items()))
X_smote.shape,y_smote.shape
#Checking out both old & new data
print('Original dataset shape {}'.format(Counter(y)))
print('Resampled dataset shape {}'.format(Counter(y_smote)))
#Creating X output to dataframe
X1=pd.DataFrame(X_smote,columns=[x])
#Creating Y output to dataframe for merging
Y1=pd.DataFrame(y_smote,columns=['b5'])
#Merging the X & Y output to Final data
dataset=pd.concat([X1,Y1],axis=1)
dataset.head()
# Out:
# [(0, 15332), (1, 15332)]
# Original dataset shape Counter({1: 15332, 0: 950})
# Resampled dataset shape Counter({1: 15332, 0: 15332})
#    (v013,)  (v024,)  (v025,)  (v106,)  (v130,)  (v190,)  (v213,)  (v409,)  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    (v411,)  (v411a,)  ...  (v414o,)  (v414p,)  (v414s,)  (v414v,)  (v445,)  \
# 0      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
# 1      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
# 2      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
# 3      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
# ...

# %%
dataset.head()
# Out:
#    (v013,)  (v024,)  (v025,)  (v106,)  (v130,)  (v190,)  (v213,)  (v409,)  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    (v411,)  (v411a,)  ...  (v414o,)  (v414p,)  (v414s,)  (v414v,)  (v445,)  \
# 0      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
# 1      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
# 2      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
# 3      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
# 4      NaN       NaN  ...       NaN       NaN       NaN       NaN      NaN
#
#    (v457,)  (b9,)  (b19,)  (m4,)  b5
# ...

# %%
# Using Matplotlib to show distribution of reviews sentiment in the dataset
print(dataset.b5.value_counts())
dataset['b5'].value_counts().plot(kind='bar')
plt.title("infant mortality ", size=18)
# Out:
# 1    15332
# 0    15332
# Name: b5, dtype: int64
# Text(0.5, 1.0, 'infant mortality ')

# %%
dataset.iloc[0:10,10:30]
# Out:
#    (v412a,)  (v412c,)  (v414e,)  (v414f,)  (v414g,)  (v414h,)  (v414i,)  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    (v414j,)  (v414k,)  (v414l,)  (v414m,)  (v414n,)  (v414o,)  (v414p,)  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
dataset.shape
# Out:
# (30664, 32)

# %%
dataset
# Out:
#        (v013,)  (v024,)  (v025,)  (v106,)  (v130,)  (v190,)  (v213,)  (v409,)  \
# 0          NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1          NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2          NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3          NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4          NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 30659      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 30660      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 30661      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 30662      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 30663      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
dataset.iloc[0:10,10:32]
# Out:
#    (v412a,)  (v412c,)  (v414e,)  (v414f,)  (v414g,)  (v414h,)  (v414i,)  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    (v414j,)  (v414k,)  (v414l,)  ...  (v414o,)  (v414p,)  (v414s,)  (v414v,)  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# ...

# %%
dataset=pd.read_csv("D:EDHS file/Data for implimation nutrrition/nutrition_final.csv")
dataset
# Out:
#        Unnamed: 0  v013  v024  v025  v106  v130  v190  v213  v409  v411  ...  \
# 0               0     1     4     2     0     0     2     0     1     0  ...
# 1               1     1     4     2     0     0     2     0     1     0  ...
# 2               2     1     4     2     0     0     2     0     1     0  ...
# 3               3     0     4     2     1     0     2     0     1     0  ...
# 4               4     0     4     2     0     0     2     0     1     0  ...
# ...           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 30009       30009     1     3     2     0     0     1     0     1     0  ...
# 30010       30010     0     8     1     0     0     0     0     1     0  ...
# 30011       30011     0     8     2     0     1     1     0     1     0  ...
# 30012       30012     1     8     1     0     1     1     0     0     0  ...
# 30013       30013     0     5     1     0     0     1     0     1     0  ...
#
# ...

# %%
dataset.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
dataset
# Out:
#        v013  v024  v025  v106  v130  v190  v213  v409  v411  v411a  ...  \
# 0         1     4     2     0     0     2     0     1     0      0  ...
# 1         1     4     2     0     0     2     0     1     0      0  ...
# 2         1     4     2     0     0     2     0     1     0      0  ...
# 3         0     4     2     1     0     2     0     1     0      0  ...
# 4         0     4     2     0     0     2     0     1     0      0  ...
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 30009     1     3     2     0     0     1     0     1     0      0  ...
# 30010     0     8     1     0     0     0     0     1     0      0  ...
# 30011     0     8     2     0     1     1     0     1     0      0  ...
# 30012     1     8     1     0     1     1     0     0     0      0  ...
# 30013     0     5     1     0     0     1     0     1     0      0  ...
#
#        v414o  v414p  v414s  v414v  v445  v457  b9  b19  m4  b5
# ...

# %%
# Using Matplotlib to show distribution of reviews sentiment in the dataset
print(dataset.b5.value_counts())
dataset['b5'].value_counts().plot(kind='bar')
plt.title("infant mortality", size=18)
# Out:
# 1    15007
# 0    15007
# Name: b5, dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-f5c901f45a2c> in <module>
#       1 # Using Matplotlib to show distribution of reviews sentiment in the dataset
#       2 print(dataset.b5.value_counts())
# ----> 3 dataset['b5'].value_counts().plot(kind='bar')
#       4 plt.title("infant mortality", size=18)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
print(dataset.corr()["b5"].abs().sort_values(ascending=False))
# Out:
# b5       1.000000
# m4       0.519360
# v414e    0.324259
# v130     0.284030
# v106     0.262806
# v414s    0.247764
# v411     0.241503
# v414f    0.204956
# v013     0.197674
# v414o    0.185258
# v414g    0.182672
# v414p    0.175498
# v414k    0.161157
# v414i    0.160148
# v457     0.158281
# v414j    0.151700
# v414l    0.146840
# v412c    0.140405
# v190     0.137318
# v414v    0.119214
# v213     0.116745
# v412a    0.113120
# b9       0.112937
# v414h    0.111791
# b19      0.104538
# v411a    0.101000
# v414m    0.085252
# v414n    0.068821
# v024     0.067310
# v445     0.020135
# v025     0.016573
# v409     0.000527
# Name: b5, dtype: float64

# %%
dataset.dtypes
# Out:
# v013     int64
# v024     int64
# v025     int64
# v106     int64
# v130     int64
# v190     int64
# v213     int64
# v409     int64
# v411     int64
# v411a    int64
# v412a    int64
# v412c    int64
# v414e    int64
# v414f    int64
# v414g    int64
# v414h    int64
# v414i    int64
# v414j    int64
# v414k    int64
# v414l    int64
# v414m    int64
# v414n    int64
# v414o    int64
# v414p    int64
# v414s    int64
# v414v    int64
# v445     int64
# v457     int64
# b9       int64
# b19      int64
# m4       int64
# b5       int64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# v013     0
# v024     0
# v025     0
# v106     0
# v130     0
# v190     0
# v213     0
# v409     0
# v411     0
# v411a    0
# v412a    0
# v412c    0
# v414e    0
# v414f    0
# v414g    0
# v414h    0
# v414i    0
# v414j    0
# v414k    0
# v414l    0
# v414m    0
# v414n    0
# v414o    0
# v414p    0
# v414s    0
# v414v    0
# v445     0
# v457     0
# b9       0
# b19      0
# m4       0
# b5       0
# dtype: int64

# %%
dataset.shape
# Out:
# (30014, 32)

# %%
x= dataset.describe()
x.pop("b5")
x=x.transpose()
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-218bfb07ff63> in <module>
# ----> 1 x= dataset.describe()
#       2 x.pop("b5")
#       3 x=x.transpose()
#       4 x
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#   10263         elif (include is None) and (exclude is None):
#   10264             # when some numerics are found, keep only numerics
# > 10265             data = self.select_dtypes(include=[np.number])
#   10266             if len(data.columns) == 0:
#   10267                 data = self
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3425         # the "union" of the logic of case 1 and case 2:
#    3426         # we get the included and excluded, and return their logical and
# ...

# %%
dataset.columns
# Out:
# Index(['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
#        'v411a', 'v412a', 'v412c', 'v414e', 'v414f', 'v414g', 'v414h', 'v414i',
#        'v414j', 'v414k', 'v414l', 'v414m', 'v414n', 'v414o', 'v414p', 'v414s',
#        'v414v', 'v445', 'v457', 'b9', 'b19', 'm4', 'b5'],
#       dtype='object')

# %%
dataset['b5'].value_counts()
# Out:
# 1    15007
# 0    15007
# Name: b5, dtype: int64

# %%
import seaborn as sns
y = dataset["v024"]
sns.countplot(y)
v024 = dataset.v024.value_counts()
print(v024)
# Out:
# 5     4433
# 4     4355
# 2     3340
# 6     3198
# 7     3184
# 3     3036
# 8     2260
# 1     2251
# 9     1716
# 10    1129
# 11    1112
# Name: v024, dtype: int64

# %%
print("1=> "+str(round(v024[1]*100/11174,2)))
print("2 => "+str(round(v024[2]*100/11174,2)))
print("3=> "+str(round(v024[3]*100/11174,2)))
print("4=> "+str(round(v024[4]*100/11174,2)))
print("5=> "+str(round(v024[5]*100/11174,2)))
print("6 => "+str(round(v024[6]*100/11174,2)))
print("7=> "+str(round(v024[7]*100/11174,2)))
print("8=> "+str(round(v024[8]*100/11174,2)))
print("9 => "+str(round(v024[9]*100/11174,2)))
print("10=> "+str(round(v024[10]*100/11174,2)))
print("11=> "+str(round(v024[11]*100/11174,2)))
# Out:
# 1=> 20.14
# 2 => 29.89
# 3=> 27.17
# 4=> 38.97
# 5=> 39.67
# 6 => 28.62
# 7=> 28.49
# 8=> 20.23
# 9 => 15.36
# 10=> 10.1
# 11=> 9.95

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.drop(labels=['b5'], axis=1), 
                                                    dataset.b5, test_size=0.2,
                                                    random_state=0)
X_train.shape, X_test.shape
# Out:
# ((24011, 31), (6003, 31))

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
sbs = SequentialFeatureSelector(RandomForestClassifier(), 
           k_features=20, 
           forward=False, 
           floating=False,
           scoring='accuracy',
           cv=2)

# %%
sbs = sbs.fit(X_train, y_train)

# %%
selected_features = X_train.columns[list(sbs.k_feature_idx_)]
print(selected_features)
# Out:
# Index(['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
#        'v412c', 'v414e', 'v414f', 'v414g', 'v414j', 'v414s', 'v445', 'v457',
#        'b9', 'b19', 'm4'],
#       dtype='object')

# %%
print(sbs.k_score_)
# Out:
# 0.9144558187378614

# %%
X_train_sfs = sbs.transform(X_train)
X_test_sfs = sbs.transform(X_test)

# %%
import os
from sklearn.model_selection import train_test_split
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
# plt.style.use('seaborn-colorblind')
# %matplotlib inline
# from feature_selection import filter_method as ft

# %%
# step forward feature selection
# select top 10 features based on the optimal roc_auc and RandomForest Classifier
sfs1 = SFS(RandomForestClassifier(n_jobs=-1,n_estimators=5), 
           k_features=20, 
           forward=True, 
           floating=False, 
           verbose=1,
           scoring='roc_auc',
           cv=3)

sfs1 = sfs1.fit(np.array(X_train), y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:   17.8s finished
# Features: 1/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   14.4s finished
# Features: 2/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   15.4s finished
# Features: 3/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   17.0s finished
# Features: 4/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   16.4s finished
# Features: 5/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   15.1s finished
# ...

# %%
selected_feat1= X_train.columns[list(sfs1.k_feature_idx_)]
selected_feat1
# Out:
# Index(['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
#        'v411a', 'v414e', 'v414g', 'v414i', 'v414p', 'v414s', 'v445', 'v457',
#        'b9', 'b19', 'm4'],
#       dtype='object')

# %%
print(sfs1.k_score_)
# Out:
# 0.9561967002024803

# %%
# step backward feature selection
# select top 10 features based on the optimal roc_auc and RandomForest Classifier
sfs2 = SFS(RandomForestClassifier(n_jobs=-1,n_estimators=5), 
           k_features=20, 
           forward=False, 
           floating=False, 
           verbose=1,
           scoring='roc_auc',
           cv=3)
sfs2 = sfs1.fit(np.array(X_train.fillna(0)), y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:   15.0s finished
# Features: 1/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   14.4s finished
# Features: 2/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   15.0s finished
# Features: 3/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   16.4s finished
# Features: 4/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   15.7s finished
# Features: 5/20[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   14.7s finished
# ...

# %%
selected_feat2= X_train.columns[list(sfs2.k_feature_idx_)]
selected_feat2
# Out:
# Index(['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
#        'v412a', 'v414e', 'v414f', 'v414n', 'v414p', 'v414s', 'v414v', 'v445',
#        'v457', 'b19', 'm4'],
#       dtype='object')

# %%
print(sfs2.k_score_)
# Out:
# 0.9558889532741527

# %%
x=['v013', 'v024', 'v025', 'v106', 'v130', 'v190', 'v213', 'v409', 'v411',
       'v412a', 'v412c', 'v414e', 'v414n', 'v414s', 'v414v', 'v445', 'v457',
       'b9', 'b19', 'm4','b5']

# %%
import pandas as pd
data= pd.read_csv("D:EDHS file/Data for implimation nutrrition/nutrition_final.csv",usecols=x)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-84df04b5cfa1> in <module>
#       1 import pandas as pd
# ----> 2 data= pd.read_csv("D:EDHS file/Data for implimation nutrrition/nutrition_final.csv",usecols=x)
#       3 data
#
# ...

# %%
data.to_csv("D:EDHS file/Data for implimation nutrrition/nutrition_selectedfeature.csv")
data
# Out:
#        v013  v024  v025  v106  v130  v190  v213  v409  v411  v412a  ...  \
# 0         1     4     2     0     0     2     0     1     0      0  ...
# 1         1     4     2     0     0     2     0     1     0      0  ...
# 2         1     4     2     0     0     2     0     1     0      0  ...
# 3         0     4     2     1     0     2     0     1     0      0  ...
# 4         0     4     2     0     0     2     0     1     0      0  ...
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 30009     1     3     2     0     0     1     0     1     0      0  ...
# 30010     0     8     1     0     0     0     0     1     0      0  ...
# 30011     0     8     2     0     1     1     0     1     0      0  ...
# 30012     1     8     1     0     1     1     0     0     0      0  ...
# 30013     0     5     1     0     0     1     0     1     0      0  ...
#
#        v414e  v414n  v414s  v414v  v445  v457  b9  b19  m4  b5
# ...

# %%
#Exhaustive Feature Selection
efs1 = EFS(RandomForestClassifier(n_jobs=-1,n_estimators=5, random_state=0), 
           min_features=1,
           max_features=10, 
           scoring='roc_auc',
           print_progress=True,
           cv=2)
# in order to shorter search time for the demonstration
# we only try all possible 1,2,3,4,5,6
# feature combinations from a dataset of 10 features

efs1 = efs1.fit(np.array(X_train[X_train.columns[0:10]].fillna(0)), y_train)
# Out:
# Features: 1023/1023

# %% [markdown]
# # GradientBoosting

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
x = dataset.drop("b5",axis=1)
y = dataset["b5"]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state=0)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (24011, 31) (24011,) (6003, 31) (6003,)

# %%
Grad_model = GradientBoostingClassifier()

# %%
model=Grad_model.fit(X_train,y_train)

# %%
predicted=Grad_model.predict(X_test)

# %%
accuracy_score(y_test,predicted)
# Out:
# 0.8512410461435949

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import BaggingClassifier
predictors = dataset.drop("b5",axis=1)
target = dataset["b5"]
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size = 0.20, random_state=0)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (24011, 31) (24011,) (6003, 31) (6003,)

# %%
B_model = BaggingClassifier()

# %%
BG_model=B_model.fit(X_train,y_train)

# %%
predicted=B_model.predict(X_test)

# %%
accuracy_score(y_test,predicted)
# Out:
# 0.9238713976345161

# %% [markdown]
# # Random foprest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
predictors = dataset.drop("b5",axis=1)
target = dataset["b5"]
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size = 0.20, random_state=0)

# %%
RF_model = RandomForestClassifier()

# %%
R_model=RF_model.fit(X_train,y_train)

# %%
predicted=RF_model.predict(X_test)

# %%
accuracy_score(y_test,predicted)
# Out:
# 0.9313676495085791

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)
#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9340329835082459

# %%
from sklearn.ensemble import RandomForestClassifier
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)
#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # bagging

# %%
# Import All the required packages from sklearn
import numpy as np
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
seed = 7
kfold = model_selection.KFold(n_splits=10)

# %%
cart = DecisionTreeClassifier()
num_trees = 100

# %%
model = BaggingClassifier(base_estimator=cart, n_estimators=num_trees, random_state=seed)

# %%
results = model_selection.cross_val_score(model, X_train, y_train,cv=kfold)
for i in range(len(results)):
    print("Model: "+str(i)+" Accuracy is: "+str(results[i]))
# Out:
# Model: 0 Accuracy is: 0.9338051623646961
# Model: 1 Accuracy is: 0.939192003331945
# Model: 2 Accuracy is: 0.9254477301124532
# Model: 3 Accuracy is: 0.9271137026239067
# Model: 4 Accuracy is: 0.9312786339025406
# Model: 5 Accuracy is: 0.929612661391087
# Model: 6 Accuracy is: 0.9358600583090378
# Model: 7 Accuracy is: 0.9308621407746772
# Model: 8 Accuracy is: 0.9287796751353603
# Model: 9 Accuracy is: 0.9329446064139941

# %%
print("Mean Accuracy is: "+str(results.mean()))
# Out:
# Mean Accuracy is: 0.9314896374359696

# %%
model.fit(X_train, y_train)
pred_label = model.predict(X_test)
nnz = np.shape(y_test)[0] - np.count_nonzero(pred_label - y_test)
acc = 100*nnz/np.shape(y_test)[0]
print('accuracy is: '+str(acc))
# Out:
# accuracy is: 93.27003165084125

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
predictors = dataset.drop("b5",axis=1)
target = dataset["b5"]
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size = 0.20, random_state=0)

# %%
Bag_model = BaggingClassifier()

# %%
B_model=Bag_model.fit(X_train,y_train)

# %%
predicted=Bag_model.predict(X_test)

# %%
accuracy_score(y_test,predicted)
# Out:
# 0.9233716475095786

# %% [markdown]
# # AdaBoost Classification

# %%
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier  # Boosting Algorithm
from sklearn.tree import DecisionTreeClassifier
import numpy as np

# %%
cart = DecisionTreeClassifier()
num_trees = 25

# %%
model = AdaBoostClassifier(base_estimator=cart, n_estimators=num_trees, learning_rate = 0.1)

# %%
model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), learning_rate=0.1,
#                    n_estimators=25)

# %%
pred_label = model.predict(X_test)
nnz = np.float(np.shape(y_test)[0] - np.count_nonzero(pred_label - y_test))
acc = 100*nnz/np.shape(y_test)[0]

# %%
print('accuracy is: '+str(acc))
# Out:
# accuracy is: 92.13726470098284

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
Ada_model = AdaBoostClassifier()

# %%
Ad_model=Ada_model.fit(X_train,y_train)

# %%
accuracy_score(y_test,predicted)
# Out:
# 0.9233716475095786

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
Gra_model = GradientBoostingClassifier()

# %%
gr_model=Gra_model.fit(X_train,y_train)

# %%
accuracy_score(y_test,predicted)
# Out:
# 0.9233716475095786
